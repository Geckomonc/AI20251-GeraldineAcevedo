# %% [markdown]
# <a href="https://colab.research.google.com/github/Geckomonc/AI20251-GeraldineAcevedo/blob/main/02_run_scripts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
train_data_file  = 'train_data.csv'
test_input_file  = 'test_data_input.csv'
test_target_file = 'test_data_target.csv'
test_preds_file  = 'test_predictions.csv'
model_file       = 'model.pkl'

# %%
import sys
python = sys.executable

# %%
# !pip install loguru
# Out:
# Requirement already satisfied: loguru in /usr/local/lib/python3.11/dist-packages (0.7.3)

# %% [markdown]
# #train a model and save it

# %%
# !$python scripts/train.py --model_file $model_file --data_file $train_data_file  --overwrite_model
# Out:
# 2025-05-24 22:56:38.558 | INFO     | __main__:<module>:23 - overwriting existing model file model.pkl
# 2025-05-24 22:56:38.558 | INFO     | __main__:<module>:28 - loading train data
# 2025-05-24 22:56:38.793 | INFO     | __main__:<module>:33 - fitting model
# 2025-05-24 22:56:38.891 | INFO     | __main__:<module>:37 - saving model to model.pkl

# %% [markdown]
# #make inference (predict) with a saved model

# %%
# !$python scripts/predict.py --model_file $model_file --input_file $test_input_file  --predictions_file $test_preds_file
# Out:
# 2025-05-24 22:56:42.263 | INFO     | __main__:<module>:27 - loading input data
# 2025-05-24 22:56:42.267 | INFO     | __main__:<module>:31 - loading model
# 2025-05-24 22:56:42.977 | INFO     | __main__:<module>:35 - making predictions
# 2025-05-24 22:56:42.978 | INFO     | __main__:<module>:38 - saving predictions to test_predictions.csv

# %% [markdown]
# #load predictions and compare with target in test

# %%
import pandas as pd
import numpy as np

preds   = pd.read_csv(test_preds_file).values
targets = pd.read_csv(test_target_file).values

acc = np.mean(preds==targets)
print (f"accuracy on test {acc:.3f}")
# Out:
# accuracy on test 0.448
